# %%
import csv
import numpy as np

# %%
experiments = [("fixed_circuit_more_participants",6,"Number of clients",["2","5","10","20","50","100"]),
                ("add_scalar",4,"Number of operations",["10","100","500","1000"]),
                ("add_secret",4,"Number of operations",["10","100","500","1000"]),
                ("mul_scalar",4,"Number of operations",["10","100","500","1000"]),
                ("mul_secret",4,"Number of operations",["10","100","500","1000"])]

# %%
def get_experiment_metrics(experiment):
    
    experiment_name = experiment[0]
    n_params = experiment[1]

    metrics = [list() for i in range(n_params)]

    with open(experiment_name+'/0_metrics.txt') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for i,row in enumerate(csv_reader):
                                
                metrics[i%n_params].append(row)

                line_count += 1
        #print(f'Processed {line_count} lines.')
        
    return np.array(metrics, dtype=float)

# %%
for experiment in experiments:
    experiment_name = experiment[0]
    n_params = experiment[1]
    
    metrics = get_experiment_metrics(experiment)
    
    print("EXPERIMENT NAME :",experiment_name)
    
    for i, m in enumerate(metrics):
        print(experiment[2], experiment[3][i])
        print("###################################################")
        print("total time mean :", np.mean(m, axis=0)[0],", total time std :", np.std(m, axis=0)[0])
        print("comput. time mean :", np.mean(m, axis=0)[1],", comput. time std :", np.std(m, axis=0)[1])
        print("bytes sent mean :", np.mean(m, axis=0)[2],", bytes sent std :", np.std(m, axis=0)[2])
        print("bytes received mean :", np.mean(m, axis=0)[3],", bytes received std :", np.std(m, axis=0)[3])
        print("###################################################")
        
    print()
    print()
# Out:
# EXPERIMENT NAME : fixed_circuit_more_participants
# Number of clients 2
# ###################################################
# total time mean : 77.2432373046875 , total time std : 22.45762605900914
# comput. time mean : 77.2432373046875 , comput. time std : 22.45762605900914
# bytes sent mean : 77.2432373046875 , bytes sent std : 22.45762605900914
# bytes received mean : 77.2432373046875 , bytes received std : 22.45762605900914
# ###################################################
# Number of clients 5
# ###################################################
# total time mean : 207.64498291015624 , total time std : 45.64237080142321
# comput. time mean : 207.64498291015624 , comput. time std : 45.64237080142321
# bytes sent mean : 207.64498291015624 , bytes sent std : 45.64237080142321
# bytes received mean : 207.64498291015624 , bytes received std : 45.64237080142321
# ###################################################
# Number of clients 10
# ###################################################
# total time mean : 699.0876831054687 , total time std : 133.90148802860335
# comput. time mean : 699.0876831054687 , comput. time std : 133.90148802860335
# bytes sent mean : 699.0876831054687 , bytes sent std : 133.90148802860335
# bytes received mean : 699.0876831054687 , bytes received std : 133.90148802860335
# ###################################################
# Number of clients 20
# ###################################################
# total time mean : 2642.8148681640623 , total time std : 508.62996209068626
# comput. time mean : 2642.8148681640623 , comput. time std : 508.62996209068626
# bytes sent mean : 2642.8148681640623 , bytes sent std : 508.62996209068626
# bytes received mean : 2642.8148681640623 , bytes received std : 508.62996209068626
# ###################################################
# Number of clients 50
# ###################################################
# total time mean : 15821.014599609374 , total time std : 3179.938600379328
# comput. time mean : 15821.014599609374 , comput. time std : 3179.938600379328
# bytes sent mean : 15821.014599609374 , bytes sent std : 3179.938600379328
# bytes received mean : 15821.014599609374 , bytes received std : 3179.938600379328
# ###################################################
# Number of clients 100
# ###################################################
# total time mean : 66359.79721679687 , total time std : 11432.486439259941
# comput. time mean : 66359.79721679687 , comput. time std : 11432.486439259941
# bytes sent mean : 66359.79721679687 , bytes sent std : 11432.486439259941
# bytes received mean : 66359.79721679687 , bytes received std : 11432.486439259941
# ###################################################
#
#
# EXPERIMENT NAME : add_scalar
# Number of operations 10
# ###################################################
# total time mean : 25.55107421875 , total time std : 6.416628838578309
# comput. time mean : 25.55107421875 , comput. time std : 6.416628838578309
# bytes sent mean : 25.55107421875 , bytes sent std : 6.416628838578309
# bytes received mean : 25.55107421875 , bytes received std : 6.416628838578309
# ###################################################
# Number of operations 100
# ###################################################
# total time mean : 26.5576171875 , total time std : 6.839670682119463
# comput. time mean : 26.5576171875 , comput. time std : 6.839670682119463
# bytes sent mean : 26.5576171875 , bytes sent std : 6.839670682119463
# bytes received mean : 26.5576171875 , bytes received std : 6.839670682119463
# ###################################################
# Number of operations 500
# ###################################################
# total time mean : 29.68997802734375 , total time std : 5.029840462220125
# comput. time mean : 29.68997802734375 , comput. time std : 5.029840462220125
# bytes sent mean : 29.68997802734375 , bytes sent std : 5.029840462220125
# bytes received mean : 29.68997802734375 , bytes received std : 5.029840462220125
# ###################################################
# Number of operations 1000
# ###################################################
# total time mean : 31.9319091796875 , total time std : 4.8061707267498806
# comput. time mean : 31.9319091796875 , comput. time std : 4.8061707267498806
# bytes sent mean : 31.9319091796875 , bytes sent std : 4.8061707267498806
# bytes received mean : 31.9319091796875 , bytes received std : 4.8061707267498806
# ###################################################
#
#
# EXPERIMENT NAME : add_secret
# Number of operations 10
# ###################################################
# total time mean : 1096.0778198242188 , total time std : 152.14935820752936
# comput. time mean : 1096.0778198242188 , comput. time std : 152.14935820752936
# bytes sent mean : 1096.0778198242188 , bytes sent std : 152.14935820752936
# bytes received mean : 1096.0778198242188 , bytes received std : 152.14935820752936
# ###################################################
# Number of operations 100
# ###################################################
# total time mean : 7340.462145996094 , total time std : 892.6752822129836
# comput. time mean : 7340.462145996094 , comput. time std : 892.6752822129836
# bytes sent mean : 7340.462145996094 , bytes sent std : 892.6752822129836
# bytes received mean : 7340.462145996094 , bytes received std : 892.6752822129836
# ###################################################
# Number of operations 500
# ###################################################
# total time mean : 35242.7594116211 , total time std : 2202.1684420887254
# comput. time mean : 35242.7594116211 , comput. time std : 2202.1684420887254
# bytes sent mean : 35242.7594116211 , bytes sent std : 2202.1684420887254
# bytes received mean : 35242.7594116211 , bytes received std : 2202.1684420887254
# ###################################################
# Number of operations 1000
# ###################################################
# total time mean : 70484.98598632813 , total time std : 5526.702269440808
# comput. time mean : 70484.98598632813 , comput. time std : 5526.702269440808
# bytes sent mean : 70484.98598632813 , bytes sent std : 5526.702269440808
# bytes received mean : 70484.98598632813 , bytes received std : 5526.702269440808
# ###################################################
#
#
# EXPERIMENT NAME : mul_scalar
# Number of operations 10
# ###################################################
# total time mean : 25.51531982421875 , total time std : 4.948599991435682
# comput. time mean : 25.51531982421875 , comput. time std : 4.948599991435682
# bytes sent mean : 25.51531982421875 , bytes sent std : 4.948599991435682
# bytes received mean : 25.51531982421875 , bytes received std : 4.948599991435682
# ###################################################
# Number of operations 100
# ###################################################
# total time mean : 33.8418701171875 , total time std : 7.652531752523606
# comput. time mean : 33.8418701171875 , comput. time std : 7.652531752523606
# bytes sent mean : 33.8418701171875 , bytes sent std : 7.652531752523606
# bytes received mean : 33.8418701171875 , bytes received std : 7.652531752523606
# ###################################################
# Number of operations 500
# ###################################################
# total time mean : 199.87147216796876 , total time std : 10.304129487655697
# comput. time mean : 199.87147216796876 , comput. time std : 10.304129487655697
# bytes sent mean : 199.87147216796876 , bytes sent std : 10.304129487655697
# bytes received mean : 199.87147216796876 , bytes received std : 10.304129487655697
# ###################################################
# Number of operations 1000
# ###################################################
# total time mean : 851.1223510742187 , total time std : 20.268404814873435
# comput. time mean : 851.1223510742187 , comput. time std : 20.268404814873435
# bytes sent mean : 851.1223510742187 , bytes sent std : 20.268404814873435
# bytes received mean : 851.1223510742187 , bytes received std : 20.268404814873435
# ###################################################
#
#
# EXPERIMENT NAME : mul_secret
# Number of operations 10
# ###################################################
# total time mean : 4454.308874511718 , total time std : 585.372197738539
# comput. time mean : 4454.308874511718 , comput. time std : 585.372197738539
# bytes sent mean : 4454.308874511718 , bytes sent std : 585.372197738539
# bytes received mean : 4454.308874511718 , bytes received std : 585.372197738539
# ###################################################
# Number of operations 100
# ###################################################
# total time mean : 44139.56354980469 , total time std : 5195.919054453191
# comput. time mean : 44139.56354980469 , comput. time std : 5195.919054453191
# bytes sent mean : 44139.56354980469 , bytes sent std : 5195.919054453191
# bytes received mean : 44139.56354980469 , bytes received std : 5195.919054453191
# ###################################################
# Number of operations 500
# ###################################################
# total time mean : 229104.37014160157 , total time std : 25306.367961244032
# comput. time mean : 229104.37014160157 , comput. time std : 25306.367961244032
# bytes sent mean : 229104.37014160157 , bytes sent std : 25306.367961244032
# bytes received mean : 229104.37014160157 , bytes received std : 25306.367961244032
# ###################################################
# Number of operations 1000
# ###################################################
# total time mean : 440859.27502441406 , total time std : 43855.954793510304
# comput. time mean : 440859.27502441406 , comput. time std : 43855.954793510304
# bytes sent mean : 440859.27502441406 , bytes sent std : 43855.954793510304
# bytes received mean : 440859.27502441406 , bytes received std : 43855.954793510304
# ###################################################
